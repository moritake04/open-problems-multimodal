# %%
import pandas as pd
import sweetviz as sv
import scipy
import numpy as np

# %% [markdown]
# read

# %%
evaluation = pd.read_csv("../../data/input/evaluation_ids.csv")

# %%
metadata = pd.read_csv("../../data/input/metadata.csv")

# %%
# cite_train_X = pd.read_hdf("../../data/input/train_cite_inputs.h5")
cite_train_X_values = scipy.sparse.load_npz("../../data/input/compressed/train_cite_inputs_values.sparse.npz")
cite_train_X_idxcol = np.load("../../data/input/compressed/train_cite_inputs_idxcol.npz", allow_pickle=True)

# %%
# cite_train_y = pd.read_hdf("../../data/input/train_cite_targets.h5")
cite_train_y_values = scipy.sparse.load_npz("../../data/input/compressed/train_cite_targets_values.sparse.npz")
cite_train_y_idxcol = np.load("../../data/input/compressed/train_cite_targets_idxcol.npz", allow_pickle=True)

# %%
# multi_train_X = pd.read_hdf("../../data/input/train_multi_inputs.h5")
multi_train_X_values = scipy.sparse.load_npz("../../data/input/compressed/train_multi_inputs_values.sparse.npz")
multi_train_X_idxcol = np.load("../../data/input/compressed/train_multi_inputs_idxcol.npz", allow_pickle=True)

# %%
# multi_train_y = pd.read_hdf("../../data/input/train_multi_targets.h5")
multi_train_y_values = scipy.sparse.load_npz("../../data/input/compressed/train_multi_targets_values.sparse.npz")
multi_train_y_idxcol = np.load("../../data/input/compressed/train_multi_targets_idxcol.npz", allow_pickle=True)

# %%
# cite_test_X = pd.read_hdf("../../data/input/test_cite_inputs.h5")
cite_test_X_values = scipy.sparse.load_npz("../../data/input/compressed/test_cite_inputs_values.sparse.npz")
cite_test_X_idxcol = np.load("../../data/input/compressed/test_cite_inputs_idxcol.npz", allow_pickle=True)

# %%
# multi_test_X = pd.read_hdf("../../data/input/test_multi_inputs.h5")
multi_test_y_values = scipy.sparse.load_npz("../../data/input/compressed/test_multi_targets_values.sparse.npz")
multi_test_y_idxcol = np.load("../../data/input/compressed/test_multi_targets_idxcol.npz", allow_pickle=True)

# %%
metadata_2 = pd.read_csv("../../data/input/metadata_cite_day_2_donor_27678.csv")
cite_test_X_2 = pd.read_hdf("../../data/input/test_cite_inputs_day_2_donor_27678.h5")

# %% [markdown]
# evaluation

# %%
evaluation
# Out:
#             row_id       cell_id          gene_id
# 0                0  c2150f55becb             CD86
# 1                1  c2150f55becb            CD274
# 2                2  c2150f55becb            CD270
# 3                3  c2150f55becb            CD155
# 4                4  c2150f55becb            CD112
# ...            ...           ...              ...
# 65744175  65744175  2c53aa67933d  ENSG00000134419
# 65744176  65744176  2c53aa67933d  ENSG00000186862
# 65744177  65744177  2c53aa67933d  ENSG00000170959
# 65744178  65744178  2c53aa67933d  ENSG00000107874
# 65744179  65744179  2c53aa67933d  ENSG00000166012
#
# [65744180 rows x 3 columns]

# %% [markdown]
# metadata

# %%
metadata
# Out:
#              cell_id  day  donor cell_type technology
# 0       c2150f55becb    2  27678       HSC    citeseq
# 1       65b7edf8a4da    2  27678       HSC    citeseq
# 2       c1b26cb1057b    2  27678      EryP    citeseq
# 3       917168fa6f83    2  27678      NeuP    citeseq
# 4       2b29feeca86d    2  27678      EryP    citeseq
# ...              ...  ...    ...       ...        ...
# 281523  96a60b026659   10  31800    hidden   multiome
# 281524  d493e546991e   10  31800    hidden   multiome
# 281525  05666c99aa48   10  31800    hidden   multiome
# 281526  121f946642b5   10  31800    hidden   multiome
# 281527  b847ba21f59f   10  31800    hidden   multiome
#
# [281528 rows x 5 columns]

# %% [markdown]
# - 欠損値無
# - cell_id -> unique
# - day -> 2, 4, 5, 7, 10
# - donor -> 4人
# - cell_type -> 8 types
# - technology -> 2
#     - citeseqは4日
#     - Multiomeは5日（4日目の27678ドナーの測定は無し）

# %% [markdown]
# h5

# %%
cite_train_X
# Out:
# gene_id       ENSG00000121410_A1BG  ENSG00000268895_A1BG-AS1  \
# cell_id
# 45006fe3e4c8                   0.0                       0.0
# d02759a80ba2                   0.0                       0.0
# c016c6b0efa5                   0.0                       0.0
# ba7f733a4f75                   0.0                       0.0
# fbcf2443ffb2                   0.0                       0.0
# ...                            ...                       ...
# 650ee456f0f3                   0.0                       0.0
# cc506e7707f5                   0.0                       0.0
# a91f1b55a520                   0.0                       0.0
# 3a9882c98205                   0.0                       0.0
# c91b6b2ccd3d                   0.0                       0.0
#
# gene_id       ENSG00000175899_A2M  ENSG00000245105_A2M-AS1  \
# cell_id
# 45006fe3e4c8                  0.0                      0.0
# d02759a80ba2                  0.0                      0.0
# ...

# %%
cnt = 0
for i in cite_test_X_2.columns:
    if i not in cite_train_X_idxcol["columns"]:
        print(f'"{i}"', end=", ")
        cnt += 1
print()
print(cnt)
# Out:
# "ENSG00000255655_AC007570.1", "ENSG00000213237_AC008155.1", "ENSG00000273398_AC017083.3", "ENSG00000233849_AC022201.2", "ENSG00000231401_AC023481.1", "ENSG00000263126_AC040162.3", "ENSG00000285876_AC093912.1", "ENSG00000275585_AC241377.2", "ENSG00000272175_AL050343.2", "ENSG00000232290_AL133260.2", "ENSG00000267559_AL158154.2", "ENSG00000273481_AL391069.4", "ENSG00000161609_CCDC155", "ENSG00000150394_CDH8", "ENSG00000233932_CTXN2", "ENSG00000198077_CYP2A7", "ENSG00000220871_DNAJC19P6", "ENSG00000267336_EIF4A2P1", "ENSG00000251254_GTF2F2P1", "ENSG00000225978_HAR1A", "ENSG00000131097_HIGD1B", "ENSG00000211897_IGHG3", "ENSG00000233080_LINC01399", "ENSG00000236849_LINC01474", "ENSG00000269904_MAP2K4P1", "ENSG00000266698_MIR3945", "ENSG00000144227_NXPH2", "ENSG00000182057_OGFRP1", "ENSG00000251107_PDCD5P2", "ENSG00000226964_RHEBP2", "ENSG00000214988_RPL7AP26", "ENSG00000248873_SERBP1P6", "ENSG00000212588_SNORA26", "ENSG00000166984_TCP10L2", "ENSG00000226051_ZNF503-AS1",
# 35

# %%
test_X_2 = pd.read_hdf("../../data/input/test_cite_inputs_day_2_donor_27678.h5").drop(["ENSG00000255655_AC007570.1", "ENSG00000213237_AC008155.1", "ENSG00000273398_AC017083.3", "ENSG00000233849_AC022201.2", "ENSG00000231401_AC023481.1", "ENSG00000263126_AC040162.3", "ENSG00000285876_AC093912.1", "ENSG00000275585_AC241377.2", "ENSG00000272175_AL050343.2", "ENSG00000232290_AL133260.2", "ENSG00000267559_AL158154.2", "ENSG00000273481_AL391069.4", "ENSG00000161609_CCDC155", "ENSG00000150394_CDH8", "ENSG00000233932_CTXN2", "ENSG00000198077_CYP2A7", "ENSG00000220871_DNAJC19P6", "ENSG00000267336_EIF4A2P1", "ENSG00000251254_GTF2F2P1", "ENSG00000225978_HAR1A", "ENSG00000131097_HIGD1B", "ENSG00000211897_IGHG3", "ENSG00000233080_LINC01399", "ENSG00000236849_LINC01474", "ENSG00000269904_MAP2K4P1", "ENSG00000266698_MIR3945", "ENSG00000144227_NXPH2", "ENSG00000182057_OGFRP1", "ENSG00000251107_PDCD5P2", "ENSG00000226964_RHEBP2", "ENSG00000214988_RPL7AP26", "ENSG00000248873_SERBP1P6", "ENSG00000212588_SNORA26", "ENSG00000166984_TCP10L2", "ENSG00000226051_ZNF503-AS1"] ,axis=1)

# %%
cite_train_X_idxcol["columns"]
# Out:
# array(['ENSG00000121410_A1BG', 'ENSG00000268895_A1BG-AS1',
#        'ENSG00000175899_A2M', ..., 'ENSG00000162378_ZYG11B',
#        'ENSG00000159840_ZYX', 'ENSG00000074755_ZZEF1'], dtype=object)

# %% [markdown]
# correlations

# %%
cite_correlations = np.load("../../data/input/correlation/correlations_citeseq.npz")

# %%
np_inputs_names = np.load("../../data/input/compressed/train_cite_inputs_idxcol.npz", allow_pickle=True)["columns"]
np_targets_names = np.load("../../data/input/compressed/train_cite_targets_idxcol.npz", allow_pickle=True)["columns"]

# %%
correlations = cite_correlations["correlations"]

# %%
most_importants_inputs = np.argsort(np.squeeze(np.asarray(np.mean(np.abs(correlations), axis=0))))[::-1]

name_col = []
mean_abs_cor_col = []
mean_cor_col = []
pc_positive_cor_col = []
pc_negative_cor_col = []
min_col = []
max_col = []

for num_input in most_importants_inputs:
    mean_abs_cor = np.mean(np.abs(correlations[:,num_input]))
    mean_cor = np.mean(correlations[:,num_input])
    pc_positive_cor = np.mean(correlations[:,num_input]>0.01)*100
    pc_negative_cor = np.mean(correlations[:,num_input]<-0.01)*100
    min_val = np.min(correlations[:,num_input])
    max_val = np.max(correlations[:,num_input])

    if max_val >= 0.3 or min_val <= -0.3:
    #if mean_abs_cor >= 0.1:
        name_col.append(np_inputs_names[num_input])
        mean_abs_cor_col.append(mean_abs_cor)
        mean_cor_col.append(mean_cor)
        pc_positive_cor_col.append(pc_positive_cor)
        pc_negative_cor_col.append(pc_negative_cor)

        min_col.append(min_val)
        max_col.append(max_val)

#     print("%s:    \t%.3f\t%.3f\t%.1f\t%.1f"%(np_inputs_names[num_input], mean_abs_cor, mean_cor, pc_positive_cor, pc_negative_cor))

pd.DataFrame({"Input":name_col,
            "avg abs cor": mean_abs_cor_col,
            "avg cor": mean_cor_col,
            "%positive": pc_positive_cor_col,
            "%negative": pc_negative_cor_col,
            "min":min_col,
            "max":max_col
            } )
# Out:
#                       Input  avg abs cor   avg cor  %positive  %negative  \
# 0    ENSG00000129824_RPS4Y1     0.212646 -0.212646   0.000000  98.571429
# 1      ENSG00000229807_XIST     0.201416  0.201172  98.571429   0.714286
# 2    ENSG00000198692_EIF1AY     0.183716 -0.182739   1.428571  97.857143
# 3     ENSG00000102145_GATA1     0.145752  0.024506  55.000000  38.571429
# 4    ENSG00000128040_SPINK2     0.142456 -0.010529  35.714286  55.714286
# ..                      ...          ...       ...        ...        ...
# 382     ENSG00000113924_HGD     0.032043  0.010498  33.571429  24.285714
# 383    ENSG00000163736_PPBP     0.031433  0.009705  19.285714  30.000000
# 384    ENSG00000182732_RGS6     0.030716  0.009949  40.000000  26.428571
# 385    ENSG00000065534_MYLK     0.030136  0.010353  25.714286  31.428571
# 386     ENSG00000088053_GP6     0.029114  0.008759  22.857143  29.285714
#
#           min       max
# 0   -0.549805 -0.000745
# 1   -0.013336  0.526367
# ...

# %%
cite_max_min_corr_03 = name_col.copy()

# %%
# %store cite_max_min_corr_03
# Out:
# Stored 'cite_max_min_corr_03' (list)

# %%
correlations = scipy.sparse.load_npz("../../data/input/correlation/correlations_multiome.sparse.npz")

# %%
np_inputs_names = np.load("../../data/input/compressed/train_multi_inputs_idxcol.npz", allow_pickle=True)["columns"]
np_targets_names = np.load("../../data/input/compressed/train_multi_targets_idxcol.npz", allow_pickle=True)["columns"]

# %%
correlations = correlations.tocsc()
most_importants_inputs = np.argsort(np.squeeze(np.asarray(np.mean(np.abs(correlations), axis=0))))[::-1]

name_col = []
mean_abs_cor_col = []
mean_cor_col = []
pc_positive_cor_col = []
pc_negative_cor_col = []
min_col = []
max_col = []

for num_input in most_importants_inputs:
    mean_abs_cor = np.mean(np.abs(correlations[:,num_input]))
    mean_cor = np.mean(correlations[:,num_input])
    pc_positive_cor = np.mean(correlations[:,num_input]>0.01)*100
    pc_negative_cor = np.mean(correlations[:,num_input]<-0.01)*100
    min_val = np.min(correlations[:,num_input])
    max_val = np.max(correlations[:,num_input])

    if max_val >= 0.15 or min_val <= -0.15:
    #if mean_abs_cor >= 0.01:
        name_col.append(np_inputs_names[num_input])
        mean_abs_cor_col.append(mean_abs_cor)
        mean_cor_col.append(mean_cor)
        pc_positive_cor_col.append(pc_positive_cor)
        pc_negative_cor_col.append(pc_negative_cor)

        min_col.append(min_val)
        max_col.append(max_val)

pd.DataFrame({"Input":name_col, 
            "avg abs cor": mean_abs_cor_col,
            "avg cor": mean_cor_col,
            "%positive": pc_positive_cor_col,
            "%negative": pc_negative_cor_col,
            "min":min_col,
            "max":max_col
            } )
# Out:
#                          Input  avg abs cor   avg cor  %positive  %negative  \
# 0       chr1:47180897-47181792     0.012873  0.006551  35.178068  10.889060
# 1      chr11:74011263-74012190     0.012008  0.005596  32.825177  11.234947
# 2       chr2:28557270-28558187     0.011738 -0.003626  11.119652  30.314288
# 3      chr19:40330825-40331742     0.011423 -0.006317   7.434452  35.020070
# 4      chr20:46215644-46216554     0.011364  0.005455  32.564694  10.500470
# ...                        ...          ...       ...        ...        ...
# 999   chr7:135286716-135287148     0.000187  0.000184   1.007772   0.017081
# 1000  chr2:130163640-130163937     0.000185  0.000177   0.986421   0.034162
# 1001  chr6:170448276-170448680     0.000177  0.000173   1.024853   0.017081
# 1002   chr16:76634942-76635337     0.000145  0.000140   0.888206   0.021351
# 1003    chr5:23951059-23951888     0.000082  0.000052   0.435562   0.106755
#
#            min       max
# 0    -0.226929  0.240967
# ...

# %%
multi_max_min_corr_015 = name_col.copy()

# %%
# %store multi_max_min_corr_015
# Out:
# Stored 'multi_max_min_corr_015' (list)

# %% [markdown]
# sweetviz

# %%
evaluation_report = sv.analyze(evaluation)
# Out:
#                                              |          | [  0%]   00:00 -> (? left)

# %%
evaluation_report.show_notebook()
# Out:
#  <iframe width="100%" height="750" srcdoc="&lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;UTF-8&quot;&gt;
#     &lt;link rel=&quot;icon&quot; href=&quot;data:image/x-icon;base64,...&quot; type=&quot;image/x-icon&quot; /&gt;
#         &lt;script&gt; /*! jQuery v3.4.1 | (c) JS Foundation and other contributors | jquery.org/license */
# ...

# %%
metadata_report = sv.analyze(metadata)
# Out:
#                                              |          | [  0%]   00:00 -> (? left)

# %%
metadata_report.show_notebook()
# Out:
#  <iframe width="100%" height="750" srcdoc="&lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;UTF-8&quot;&gt;
#     &lt;link rel=&quot;icon&quot; href=&quot;data:image/x-icon;base64,...&quot; type=&quot;image/x-icon&quot; /&gt;
#         &lt;script&gt; /*! jQuery v3.4.1 | (c) JS Foundation and other contributors | jquery.org/license */
# ...
